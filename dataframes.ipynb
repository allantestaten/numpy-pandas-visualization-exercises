# %%
#1. 
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df['passing_english'] = df.english > 70

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
df.sort_values(by='passing_english')

#duplicates are listed out
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
#df.sort_values(by='passing_english', by='name')
df.sort_values(by=['passing_english','name',], inplace =True)

df
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
#df.sort_values(by='passing_english', by='name')
df.sort_values(by=['passing_english','english',], inplace =True)

df
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
df['average_grade'] = ((df.math + df.english + df.reading)//3)

# %%
df
# Out:
#        name  math  english  reading  passing_english  average_grade
# 11     Alan    92       62       72            False             75
# 8    Albert    92       62       87            False             80
# 7     Marie    93       63       90            False             82
# 6    Thomas    82       64       81            False             75
# 2     Suzie    94       74       95             True             87
# 5      John    79       76       93             True             82
# 1      Jane    88       79       67             True             78
# 9   Richard    69       80       94             True             81
# 0     Sally    62       85       80             True             75
# 4       Ada    77       92       98             True             89
# 3     Billy    98       96       88             True             94
# 10    Isaac    92       99       93             True             94

# %%
#Break break next set of problems

# %%
# data('mpg', show_doc=True) # view the documentation for the dataset
#mpg = data('mpg') # load the dataset and store it in a variable

from pydataset import data
# Out:
# initiated datasets repo at: /Users/allantestaten/.pydataset/

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg = data('mpg')

# %%
df.mpg = pd.DataFrame(mpg)
# Out:
# /var/folders/f1/m4_s2k_97xng0khbnvxb1jbw0000gn/T/ipykernel_34905/4003538738.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.mpg = pd.DataFrame(mpg)

# %%
234 Rows and 11 Columns

# %%
df.mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
df.mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
df.mpg.rename(columns={'hwy': 'highway'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
#df['passing_english'] = df.english > 70
df.mpg['city greater than hwy'] = df.mpg.cty > df.mpg.hwy

df.mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  city greater than hwy
# 1    compact                  False
# ...

# %%
#df.sort_values(by=['passing_english','english',], inplace =True)
df.mpg.sort_values(by='city greater than hwy', ascending = False)

#no cars have better city mileage than Hwy
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 1           audi               a4    1.8  1999    4    auto(l5)   f   18   29
# 161       subaru     forester awd    2.5  1999    4    auto(l4)   4   18   24
# 149       nissan           maxima    3.0  1999    6  manual(m5)   f   19   25
# 150       nissan           maxima    3.5  2008    6    auto(av)   f   19   25
# 151       nissan   pathfinder 4wd    3.3  1999    6    auto(l4)   4   14   17
# ..           ...              ...    ...   ...  ...         ...  ..  ...  ...
# 83          ford     explorer 4wd    5.0  1999    8    auto(l4)   4   13   17
# 84          ford  f150 pickup 4wd    4.2  1999    6    auto(l4)   4   14   17
# 85          ford  f150 pickup 4wd    4.2  1999    6  manual(m5)   4   14   17
# 86          ford  f150 pickup 4wd    4.6  1999    8  manual(m5)   4   13   16
# 234   volkswagen           passat    3.6  2008    6    auto(s6)   f   17   26
#
# ...

# %%
df.mpg['mileage_difference'] = df.mpg.hwy - df.mpg.cty

df.mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  city greater than hwy  mileage_difference  mileage
# ...

# %%
df.mpg['average_mileage'] = ((df.mpg.hwy + df.mpg.cty)//2)
df.mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  city greater than hwy  mileage_difference  mileage  \
# ...

# %%
#df.mpg.sort_values(by=['average_mileage','manufacturer' = 'dodge','model'], inplace =True)
#df.mpg['average_mileage'] = ((df.mpg.hwy + df.mpg.cty)//2)
#df.mpg.sort_values(by='city greater than hwy', ascending = False)

df.mpg['dodge'] = df.mpg.manufacturer = 'dodge'

print(df.mpg.sort_values(by = 'average_mileage', ascending = False))
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 222        dodge           new beetle    1.9  1999    4  manual(m5)   f   35
# 213        dodge                jetta    1.9  1999    4  manual(m5)   f   33
# 223        dodge           new beetle    1.9  1999    4    auto(l4)   f   29
# 197        dodge              corolla    1.8  2008    4  manual(m5)   f   28
# 198        dodge              corolla    1.8  2008    4    auto(l4)   f   26
# ..           ...                  ...    ...   ...  ...         ...  ..  ...
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 127        dodge   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
#
# ...

# %%
#Third part 
Mammals = data
from pydataset import data

# %%
Mammals = data('Mammals')

# %%
data('Mammals', show_doc=True)

# 107 rows, 4 columns
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %%
df.mam = pd.DataFrame(Mammals)

df.mam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
df.mam.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
df.mam.sort_values('speed', ascending = False).head(1)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
len(df.mam) total length 
specials count 
len(df.mam)
# Out:
# 107

# %%
df.mam

# 0 % of specials 

#df.mpg['dodge'] = df.mpg.manufacturer = 'dodge'
# Out:
#        weight  speed  hoppers  specials  are_specials
# 1    6000.000   35.0    False     False         False
# 2    4000.000   26.0    False     False         False
# 3    3000.000   25.0    False     False         False
# 4    1400.000   45.0    False     False         False
# 5     400.000   70.0    False     False         False
# 6     350.000   70.0    False     False         False
# 7     300.000   64.0    False     False         False
# 8     260.000   70.0    False     False         False
# 9     250.000   40.0    False     False         False
# 10   3800.000   25.0    False     False          True
# 11   1000.000   60.0    False     False         False
# 12    900.000   70.0    False     False         False
# 13    900.000   56.0    False     False         False
# 14    800.000   29.0    False     False         False
# 15    750.000   57.0    False     False         False
# 16    500.000   32.0    False     False         False
# ...

# %%
df.mam.hoppers

#df.mpg['dodge'] = df.mpg.manufacturer = 'dodge'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [142], in <cell line: 1>()
# ----> 1 df.mam.hoppers(True)
#
# TypeError: 'Series' object is not callable
